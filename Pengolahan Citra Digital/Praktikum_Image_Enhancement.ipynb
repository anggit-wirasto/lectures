# %% [markdown]
# # Praktikum Image Enhancement
# Modul ini akan membimbing Anda melalui berbagai teknik peningkatan citra digital menggunakan Python dan OpenCV.

# %% [markdown]
# ## 1. Persiapan Lingkungan

# %%
# !pip install opencv-python matplotlib

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Load Gambar Grayscale

# %%
# Gantilah 'image.jpg' dengan path gambar Anda
img = cv2.imread('images/chestxray.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')
plt.title('Original Image')
plt.axis('off')
plt.show()

# %% [markdown]
# ## 3. Histogram Equalization

# %%
hist_eq = cv2.equalizeHist(img)
plt.imshow(hist_eq, cmap='gray')
plt.title('Histogram Equalized')
plt.axis('off')
plt.show()

# %% [markdown]
# ## 4. Sharpening dengan Laplacian

# %%
laplacian = cv2.Laplacian(img, cv2.CV_64F)
sharpened = cv2.convertScaleAbs(img - 0.5 * laplacian)
plt.imshow(sharpened, cmap='gray')
plt.title('Sharpened Image')
plt.axis('off')
plt.show()

# %% [markdown]
# ## 5. Perbandingan Semua Hasil

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1), plt.imshow(img, cmap='gray'), plt.title('Original')
plt.subplot(1, 3, 2), plt.imshow(hist_eq, cmap='gray'), plt.title('Histogram Equalized')
plt.subplot(1, 3, 3), plt.imshow(sharpened, cmap='gray'), plt.title('Sharpened')
plt.show()
